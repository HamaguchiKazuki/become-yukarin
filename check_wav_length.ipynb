# %%
import os
import wave
wav_limit_length = 0

while True:
    print('now limit: ', wav_limit_length)
    # npy files delete
    # !rm dat/out_2nd_yukari_many_npy/*.npy
    print('rm all npy')

    # check wav_length
    path = "./dat/in_2nd_yukari_many_wav/"
    files = os.listdir(path)

    for file in sorted(files):
        if file != ".keep":
            wavfile = wave.open(path + file, "r")
            wav_length = float(wavfile.getnframes()) / wavfile.getframerate()
            if wav_length < wav_limit_length:
                os.remove(path + file)
                print('rm file', file)

    try:
        # !python scripts/extract_spectrogram_pair.py -i dat/in_2nd_yukari_many_wav -o dat/out_2nd_yukari_many_npy
        # !python train_sr.py dat/config_sr.json dat/model/yukari_2nd
        wav_limit_length += 0.1
    except:
        pass
# Out:
# now limit:  0
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  2.99it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.1
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.17it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.2
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.26it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.30000000000000004
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.32it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.4
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.36it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.5
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.42it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.6
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.32it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.7
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.38it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.7999999999999999
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 25/25 [00:03<00:00,  7.43it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 6 != 7
# now limit:  0.8999999999999999
# rm all npy
# rm file v_0011.wav
# rm file v_0029.wav
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 23/23 [00:03<00:00,  7.11it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss
# Exception in main training loop:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 2 != 3
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# Will finalize trainer extensions and updater before reraising the exception.
# Traceback (most recent call last):
#   File "train_sr.py", line 85, in <module>
#     trainer.run()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 330, in run
#     six.reraise(*sys.exc_info())
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/six.py", line 693, in reraise
#     raise value
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/trainer.py", line 319, in run
#     entry.extension(self)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 157, in __call__
#     result = self.evaluate()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/training/extensions/evaluator.py", line 211, in evaluate
#     eval_func(**in_arrays)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/updater/sr_updater.py", line 61, in forward
#     output = self.predictor(input)
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 101, in __call__
#     return self.decoder(self.encoder(x))
#   File "/home/aideep2018a/become-yukarin/become_yukarin/model/sr_model.py", line 85, in __call__
#     h = F.concat([h, hs[-i - 1]])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 105, in concat
#     y, = Concat(axis).apply(xs)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 243, in apply
#     self._check_data_type_forward(in_data)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/function_node.py", line 328, in _check_data_type_forward
#     self.check_type_forward(in_type)
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/array/concat.py", line 41, in check_type_forward
#     type_check.expect(in_types[0].shape[d] == in_types[i].shape[d])
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 524, in expect
#     expr.expect()
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/utils/type_check.py", line 482, in expect
#     '{0} {1} {2}'.format(left, self.inv, right))
# chainer.utils.type_check.InvalidType:
# Invalid operation is performed in: Concat (Forward)
#
# Expect: in_types[0].shape[2] == in_types[1].shape[2]
# Actual: 2 != 3
# now limit:  0.9999999999999999
# rm all npy
# rm file v_0030.wav
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
# 100%|███████████████████████████████████████████| 22/22 [00:03<00:00,  6.91it/s]
# /home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py:67: UserWarning: A batch with no more than one sample has been given to F.batch_normalization. F.batch_normalization will always output a zero tensor for such batches. This could be caused by incorrect configuration in your code (such as running evaluation while chainer.config.train=True), but could also happen in the last batch of training if non-repeating iterator is used.
#   UserWarning)
# predictor/loss

# %%
import os
import wave
# check wav_length
path = "./dat/in_2nd_yukari_many_wav/"
files = os.listdir(path)

for file in sorted(files):
    if file != ".keep":
        wavfile = wave.open(path + file, "r")
        wav_length = float(wavfile.getnframes()) / wavfile.getframerate()
        os.remove(path + file)
        print('rm file', file)
# Out:
# rm file v_0001.wav
# rm file v_0002.wav
# rm file v_0003.wav
# rm file v_0004.wav
# rm file v_0005.wav
# rm file v_0006.wav
# rm file v_0007.wav
# rm file v_0008.wav
# rm file v_0009.wav
# rm file v_0010.wav
# rm file v_0011.wav
# rm file v_0012.wav
# rm file v_0013.wav
# rm file v_0014.wav
# rm file v_0016.wav
# rm file v_0021.wav
# rm file v_0022.wav
# rm file v_0023.wav
# rm file v_0024.wav
# rm file v_0025.wav
# rm file v_0026.wav
# rm file v_0027.wav
# rm file v_0028.wav
# rm file v_0029.wav
# rm file v_0030.wav
# rm file v_0031.wav
# rm file v_0032.wav
# rm file v_0033.wav
# rm file v_0034.wav
# rm file v_0037.wav
# rm file v_0038.wav
# rm file v_0039.wav
# rm file v_0040.wav
# rm file v_0042.wav
# rm file v_0043.wav
# rm file v_0044.wav
# rm file v_0045.wav
# rm file v_0046.wav
# rm file v_0047.wav
# rm file v_0049.wav
# rm file v_0050.wav
# rm file v_0052.wav
# rm file v_0053.wav
# rm file v_0054.wav
# rm file v_0055.wav
# rm file v_0056.wav
# rm file v_0062.wav
# rm file v_0063.wav
# rm file v_0064.wav
# rm file v_0065.wav
# rm file v_0067.wav
# rm file v_0068.wav
# rm file v_0072.wav
# rm file v_0073.wav
# rm file v_0074.wav
# rm file v_0075.wav
# rm file v_0076.wav
# rm file v_0077.wav
# rm file v_0078.wav
# rm file v_0079.wav
# rm file v_0080.wav
# rm file v_0081.wav
# rm file v_0082.wav
# rm file v_0083.wav
# rm file v_0084.wav
# rm file v_0085.wav
# rm file v_0086.wav
# rm file v_0088.wav
# rm file v_0090.wav
# rm file v_0091.wav
# rm file v_0092.wav
# rm file v_0093.wav
# rm file v_0094.wav
# rm file v_0097.wav
# rm file v_0099.wav
# rm file v_0100.wav
# rm file v_0103.wav
# rm file v_0104.wav
# rm file v_0105.wav
# rm file v_0106.wav
# rm file v_0107.wav
# rm file v_0108.wav
# rm file v_0110.wav
# rm file v_0111.wav
# rm file v_0112.wav
# rm file v_0113.wav
# rm file v_0114.wav
# rm file v_0116.wav
# rm file v_0117.wav
# rm file v_0118.wav
# rm file v_0119.wav
# rm file v_0120.wav
# rm file v_0121.wav
# rm file v_0122.wav
# rm file v_0123.wav
# rm file v_0124.wav
# rm file v_0125.wav
# rm file v_0126.wav
# rm file v_0127.wav
# rm file v_0128.wav
# rm file v_0129.wav
# rm file v_0130.wav
# rm file v_0132.wav
# rm file v_0133.wav
# rm file v_0134.wav
# rm file v_0135.wav
# rm file v_0136.wav
# rm file v_0137.wav
# rm file v_0138.wav
# rm file v_0139.wav
# rm file v_0140.wav
# rm file v_0141.wav
# rm file v_0143.wav
# rm file v_0144.wav
# rm file v_0146.wav
# rm file v_0147.wav
# rm file v_0148.wav
# rm file v_0149.wav
# rm file v_0150.wav
# rm file v_0151.wav
# rm file v_0153.wav
# rm file v_0155.wav
# rm file v_0156.wav
# rm file v_0157.wav
# rm file v_0158.wav
# rm file v_0159.wav
# rm file v_0160.wav
# rm file v_0161.wav
# rm file v_0162.wav
# rm file v_0163.wav
# rm file v_0164.wav
# rm file v_0165.wav
# rm file v_0166.wav
# rm file v_0167.wav
# rm file v_0168.wav
# rm file v_0169.wav
# rm file v_0170.wav
# rm file v_0171.wav
# rm file v_0172.wav
# rm file v_0173.wav
# rm file v_0174.wav
# rm file v_0175.wav
# rm file v_0176.wav
# rm file v_0177.wav
# rm file v_0178.wav
# rm file v_0179.wav
# rm file v_0180.wav
# rm file v_0181.wav
# rm file v_0182.wav
# rm file v_0183.wav
# rm file v_0184.wav
# rm file v_0185.wav
# rm file v_0186.wav
# rm file v_0187.wav
# rm file v_0188.wav
# rm file v_0189.wav
# rm file v_0190.wav
# rm file v_0191.wav
# rm file v_0192.wav
# rm file v_0193.wav
# rm file v_0194.wav
# rm file v_0195.wav
# rm file v_0196.wav
# rm file v_0197.wav
# rm file v_0198.wav
# rm file v_0199.wav
# rm file v_0200.wav
# rm file v_0201.wav
# rm file v_0202.wav
# rm file v_0203.wav
# rm file v_0204.wav
# rm file v_0205.wav
# rm file v_0206.wav
# rm file v_0207.wav
# rm file v_0208.wav
# rm file v_0209.wav
# rm file v_0210.wav
# rm file v_0211.wav
# rm file v_0212.wav
# rm file v_0213.wav
# rm file v_0214.wav
# rm file v_0215.wav
# rm file v_0216.wav
# rm file v_0217.wav
# rm file v_0218.wav
# rm file v_0219.wav
# rm file v_0220.wav
# rm file v_0221.wav
# rm file v_0222.wav
# rm file v_0223.wav
# rm file v_0224.wav
# rm file v_0225.wav
# rm file v_0226.wav
# rm file v_0227.wav
# rm file v_0228.wav
# rm file v_0229.wav
# rm file v_0230.wav
# rm file v_0231.wav
# rm file v_0232.wav
# rm file v_0233.wav
# rm file v_0234.wav
# rm file v_0235.wav
# rm file v_0236.wav
# rm file v_0237.wav
# rm file v_0238.wav
# rm file v_0239.wav
# rm file v_0240.wav
# rm file v_0241.wav
# rm file v_0242.wav
# rm file v_0243.wav
# rm file v_0244.wav
# rm file v_0245.wav
# rm file v_0246.wav
# rm file v_0247.wav
# rm file v_0248.wav
# rm file v_0249.wav
# rm file v_0250.wav
# rm file v_0251.wav
# rm file v_0252.wav
# rm file v_0253.wav
# rm file v_0254.wav
# rm file v_0255.wav
# rm file v_0256.wav
# rm file v_0257.wav
# rm file v_0258.wav
# rm file v_0259.wav
# rm file v_0260.wav
# rm file v_0261.wav
# rm file v_0262.wav
# rm file v_0263.wav
# rm file v_0264.wav
# rm file v_0265.wav
# rm file v_0266.wav
# rm file v_0267.wav
# rm file v_0268.wav
# rm file v_0269.wav
# rm file v_0270.wav
# rm file v_0271.wav
# rm file v_0272.wav
# rm file v_0273.wav
# rm file v_0274.wav
# rm file v_0275.wav
# rm file v_0276.wav
# rm file v_0277.wav
# rm file v_0278.wav
# rm file v_0279.wav
# rm file v_0280.wav
# rm file v_0281.wav
# rm file v_0282.wav
# rm file v_0283.wav
# rm file v_0284.wav
# rm file v_0285.wav
# rm file v_0286.wav
# rm file v_0287.wav
# rm file v_0288.wav
# rm file v_0289.wav
# rm file v_0290.wav
# rm file v_0291.wav
# rm file v_0292.wav
# rm file v_0293.wav
# rm file v_0294.wav
# rm file v_0295.wav
# rm file v_0296.wav
# rm file v_0297.wav
# rm file v_0298.wav
# rm file v_0299.wav
# rm file v_0300.wav
# rm file v_0301.wav
# rm file v_0302.wav
# rm file v_0303.wav
# rm file v_0304.wav
# rm file v_0305.wav
# rm file v_0306.wav
# rm file v_0307.wav
# rm file v_0308.wav
# rm file v_0309.wav
# rm file v_0310.wav
# rm file v_0311.wav
# rm file v_0312.wav
# rm file v_0313.wav
# rm file v_0314.wav
# rm file v_0315.wav
# rm file v_0316.wav
# rm file v_0317.wav
# rm file v_0318.wav
# rm file v_0319.wav
# rm file v_0320.wav
# rm file v_0321.wav
# rm file v_0322.wav
# rm file v_0323.wav
# rm file v_0324.wav
# rm file v_0325.wav
# rm file v_0326.wav
# rm file v_0327.wav
# rm file v_0328.wav
# rm file v_0329.wav
# rm file v_0330.wav
# rm file v_0331.wav
# rm file v_0332.wav
# rm file v_0333.wav
# rm file v_0334.wav
# rm file v_0335.wav
# rm file v_0336.wav
# rm file v_0337.wav
# rm file v_0338.wav
# rm file v_0339.wav
# rm file v_0340.wav
# rm file v_0341.wav
# rm file v_0342.wav
# rm file v_0343.wav
# rm file v_0344.wav
# rm file v_0345.wav
# rm file v_0346.wav
# rm file v_0347.wav
# rm file v_0348.wav
# rm file v_0349.wav
# rm file v_0350.wav
# rm file v_0351.wav
# rm file v_0352.wav
# rm file v_0353.wav
# rm file v_0354.wav
# rm file v_0355.wav
# rm file v_0356.wav
# rm file v_0357.wav
# rm file v_0358.wav
# rm file v_0359.wav
# rm file v_0360.wav
# rm file v_0361.wav
# rm file v_0362.wav
# rm file v_0363.wav
# rm file v_0364.wav
# rm file v_0365.wav
# rm file v_0366.wav
# rm file v_0367.wav
# rm file v_0368.wav
# rm file v_0369.wav
# rm file v_0370.wav
# rm file v_0371.wav
# rm file v_0372.wav
# rm file v_0373.wav
# rm file v_0374.wav
# rm file v_0375.wav
# rm file v_0376.wav
# rm file v_0377.wav
# rm file v_0378.wav
# rm file v_0379.wav
# rm file v_0380.wav
# rm file v_0381.wav
# rm file v_0382.wav
# rm file v_0383.wav
# rm file v_0384.wav
# rm file v_0385.wav
# rm file v_0386.wav
# rm file v_0387.wav
# rm file v_0388.wav
# rm file v_0389.wav
# rm file v_0390.wav
# rm file v_0391.wav
# rm file v_0392.wav
# rm file v_0393.wav
# rm file v_0394.wav
# rm file v_0395.wav
# rm file v_0396.wav
# rm file v_0397.wav
# rm file v_0398.wav
# rm file v_0399.wav
# rm file v_0400.wav
# rm file v_0401.wav
# rm file v_0402.wav
# rm file v_0403.wav
# rm file v_0404.wav
# rm file v_0405.wav
# rm file v_0406.wav
# rm file v_0407.wav
# rm file v_0408.wav
# rm file v_0409.wav
# rm file v_0410.wav
# rm file v_0411.wav
# rm file v_0412.wav
# rm file v_0413.wav
# rm file v_0414.wav
# rm file v_0415.wav
# rm file v_0416.wav
# rm file v_0417.wav
# rm file v_0418.wav
# rm file v_0419.wav
# rm file v_0420.wav
# rm file v_0421.wav
# rm file v_0422.wav
# rm file v_0423.wav
# rm file v_0424.wav
# rm file v_0425.wav
# rm file v_0426.wav
# rm file v_0427.wav
# rm file v_0428.wav
# rm file v_0429.wav
# rm file v_0430.wav
# rm file v_0431.wav
# rm file v_0432.wav
# rm file v_0433.wav
# rm file v_0434.wav
# rm file v_0435.wav
# rm file v_0436.wav
# rm file v_0437.wav
# rm file v_0438.wav
# rm file v_0439.wav
# rm file v_0440.wav
# rm file v_0441.wav
# rm file v_0442.wav
# rm file v_0443.wav
# rm file v_0444.wav
# rm file v_0445.wav
# rm file v_0446.wav
# rm file v_0447.wav
# rm file v_0448.wav
# rm file v_0449.wav
# rm file v_0450.wav
# rm file v_0451.wav
# rm file v_0452.wav
# rm file v_0453.wav
# rm file v_0454.wav
# rm file v_0455.wav
# rm file v_0456.wav
# rm file v_0457.wav
# rm file v_0458.wav
# rm file v_0459.wav
# rm file v_0460.wav
# rm file v_0461.wav
# rm file v_0462.wav
# rm file v_0463.wav
# rm file v_0464.wav
# rm file v_0465.wav
# rm file v_0466.wav
# rm file v_0467.wav
# rm file v_0468.wav
# rm file v_0469.wav
# rm file v_0470.wav
# rm file v_0471.wav
# rm file v_0472.wav
# rm file v_0473.wav
# rm file v_0474.wav
# rm file v_0475.wav
# rm file v_0476.wav
# rm file v_0477.wav
# rm file v_0478.wav
# rm file v_0479.wav
# rm file v_0480.wav
# rm file v_0481.wav
# rm file v_0482.wav
# rm file v_0483.wav
# rm file v_0484.wav
# rm file v_0485.wav
# rm file v_0486.wav
# rm file v_0487.wav
# rm file v_0488.wav
# rm file v_0489.wav
# rm file v_0491.wav
# rm file v_0492.wav
# rm file v_0493.wav
# rm file v_0494.wav
# rm file v_0495.wav
# rm file v_0496.wav
# rm file v_0497.wav
# rm file v_0498.wav
# rm file v_0499.wav
# rm file v_0500.wav
# rm file v_0501.wav
# rm file v_0502.wav
# rm file v_0503.wav
# rm file v_0504.wav
# rm file v_0505.wav
# rm file v_0506.wav
# rm file v_0507.wav
# rm file v_0508.wav
# rm file v_0509.wav
# rm file v_0510.wav
# rm file v_0511.wav
# rm file v_0512.wav
# rm file v_0513.wav
# rm file v_0514.wav
# rm file v_0515.wav
# rm file v_0516.wav
# rm file v_0517.wav
# rm file v_0518.wav
# rm file v_0519.wav
# rm file v_0520.wav
# rm file v_0521.wav
# rm file v_0522.wav
# rm file v_0523.wav
# rm file v_0524.wav
# rm file v_0525.wav
# rm file v_0526.wav
# rm file v_0527.wav
# rm file v_0528.wav
# rm file v_0529.wav
# rm file v_0530.wav
