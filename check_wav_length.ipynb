# %%
import os
import wave
wav_limit_length = 0

while True:
    print('now limit: ', wav_limit_length)
    # npy files delete
    # !rm dat/out_2nd_yukari_many_npy/*.npy
    print('rm all npy')

    # check wav_length
    path = "./dat/in_2nd_yukari_many_wav/"
    files = os.listdir(path)

    for file in sorted(files):
        if file != ".keep":
            wavfile = wave.open(path + file, "r")
            wav_length = float(wavfile.getnframes()) / wavfile.getframerate()
            if wav_length < wav_limit_length:
                os.remove(path + file)
                print('rm file', file)

    try:
        # !python scripts/extract_spectrogram_pair.py -i dat/in_2nd_yukari_many_wav -o dat/out_2nd_yukari_many_npy
        # !python train_sr.py dat/config_sr.json dat/model/yukari_2nd
        wav_limit_length += 0.1
    except:
        pass
# Out:
# now limit:  0
# rm all npy
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_args',
#  '_get_kwargs',
#  'alpha',
#  'enable_overwrite',
#  'f0_estimating_method',
#  'frame_period',
#  'input_directory',
#  'order',
#  'output_directory',
#  'pad_second',
#  'sample_rate',
#  'top_db']
#  65%|█████████████████████████▍             | 1298/1986 [07:23<05:02,  2.27it/s]multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/aideep2018a/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/multiprocessing/pool.py", line 119, in worker
# ...

# %%
import os
import wave
# check wav_length
path = "./dat/in_2nd_yukari_many_wav/"
files = os.listdir(path)

for file in sorted(files):
    if file != ".keep":
        wavfile = wave.open(path + file, "r")
        wav_length = float(wavfile.getnframes()) / wavfile.getframerate()
        os.remove(path + file)
        print('rm file', file)
# Out:
# rm file v_0001.wav
# rm file v_0002.wav
# rm file v_0003.wav
# rm file v_0004.wav
# rm file v_0005.wav
# rm file v_0006.wav
# rm file v_0007.wav
# rm file v_0008.wav
# rm file v_0009.wav
# rm file v_0010.wav
# rm file v_0011.wav
# rm file v_0012.wav
# rm file v_0013.wav
# rm file v_0014.wav
# rm file v_0016.wav
# rm file v_0021.wav
# rm file v_0022.wav
# rm file v_0023.wav
# rm file v_0024.wav
# rm file v_0025.wav
# rm file v_0026.wav
# rm file v_0027.wav
# rm file v_0028.wav
# rm file v_0029.wav
# rm file v_0030.wav
# rm file v_0031.wav
# rm file v_0032.wav
# rm file v_0033.wav
# rm file v_0034.wav
# rm file v_0037.wav
# rm file v_0038.wav
# rm file v_0039.wav
# rm file v_0040.wav
# rm file v_0042.wav
# rm file v_0043.wav
# rm file v_0044.wav
# rm file v_0045.wav
# rm file v_0046.wav
# rm file v_0047.wav
# rm file v_0049.wav
# rm file v_0050.wav
# rm file v_0052.wav
# rm file v_0053.wav
# rm file v_0054.wav
# rm file v_0055.wav
# rm file v_0056.wav
# rm file v_0062.wav
# ...
